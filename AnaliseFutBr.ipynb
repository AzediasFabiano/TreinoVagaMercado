# %% [markdown]
# <a href="https://colab.research.google.com/github/AzediasFabiano/TreinoVagaMercado/blob/main/AnaliseFutBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Analise Brasileirão Rodada 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# - Dados coletados do SofaScore

# %%
rodada1 = pd.DataFrame({
    "Times": ["AtleticoGO", "Flamengo", "Palmeiras", "Ceara", "Fluminense", "Santos", "Coritiba", "Goias", "AtleticoMG",
              "Internacional", "Botafogo", "Corinthians", "Fortaleza", "Cuiaba", "Avai", "AmericaMG", "Sao Paulo",
              "AthleticoPR", "Juventude", "RBBragantino"],
    "Gols":           [1, 1, 2, 3, 0, 0, 3, 0, 2, 0, 1, 3, 0, 1, 1, 0, 4, 0, 2, 2],
    "Assistencias":   [1, 1, 1, 0, 0, 0, 2, 0, 2, 0, 0, 3, 0, 0, 0, 0, 3, 0, 0, 1],
    "FinalizaçaoGol": [3, 3, 4, 9, 6, 1, 9, 0, 5, 1, 4, 8, 5, 4, 2, 1, 8, 0, 7, 2],
    "GrandesChances": [6, 4, 3, 2, 3, 0, 2, 1, 7, 1, 2, 5, 2, 0, 0, 1, 1, 0, 2, 1],
})

# %%
rodada1.tail()
# Out:
#            Times  Gols  Assistencias  FinalizaçaoGol  GrandesChances
# 15     AmericaMG     0             0               1               1
# 16     Sao Paulo     4             3               8               1
# 17   AthleticoPR     0             0               0               0
# 18     Juventude     2             0               7               2
# 19  RBBragantino     2             1               2               1

# %%
rodada1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Times           20 non-null     object
#  1   Gols            20 non-null     int64
#  2   Assistencias    20 non-null     int64
#  3   FinalizaçaoGol  20 non-null     int64
#  4   GrandesChances  20 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 928.0+ bytes

# %%
#Criando um arquivo csv com o dataframe
#rodada1.to_csv('rodada1_Br.csv')

# %%
plt.figure(figsize=(18, 6))
plt.plot(rodada1.loc[:, "Times"], rodada1.loc[:, "Assistencias"], color='orange', label='Assistencias')
plt.plot(rodada1.loc[:, "Times"], rodada1.loc[:, "FinalizaçaoGol"], color='blue', label='FinalizaçaoGol')
plt.plot(rodada1.loc[:, "Times"], rodada1.loc[:, "GrandesChances"], color='black', label='GrandesChances')
plt.plot(rodada1.loc[:, "Times"], rodada1.loc[:, "Gols"], color='red', label='Gols')
plt.xticks(rotation=40, fontsize=16, fontweight='bold')
plt.yticks(np.arange(0, 10, 1), fontsize=12, fontweight='bold')
plt.title('Rodada 1 do Brasileirão: Estatística de: Gols x Assistências x Finalizações no gol x Grandes chances', fontsize=16, fontweight='bold', fontstyle='italic')
plt.legend()

# %% [markdown]
# -Correlação entre os indices

# %%
corr_mat = rodada1[['Gols', 'Assistencias', 'FinalizaçaoGol', 'GrandesChances']].corr()
mask = np.array(corr_mat)
mask[np.tril_indices_from(mask)] = False
sns.heatmap(corr_mat, mask=mask, square=True, annot=True)
plt.title('Correlação dos índices', fontsize=16, fontweight='bold', fontstyle='italic')
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# ###Analise Brasileirão Rodada 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
rodada2 = pd.DataFrame({
    "Times": ["Goias", "Palmeiras", "AmericaMG", "Juventude", "Corinthians", "Avai", "Cuiaba", "Fluminense", "Santos", "Coritiba", "Flamengo", "Sao Paulo", "RBBragantino", "AtleticoGO",
              "Internacional", "Fortaleza", "AthleticoPR", "AtleticoMG", "Ceara", "Botafogo"],
    "Gols":           [1, 1, 4, 1, 3, 0, 0, 1, 2, 1, 3, 1, 4, 0, 2, 1, 0, 1, 1, 3],
    "Assistencias":   [1, 0, 3, 1, 2, 0, 0, 0, 0, 0, 3, 1, 3, 0, 1, 0, 0, 0, 0, 2],
    "FinalizaçaoGol": [6, 6, 9, 4, 4, 5, 1, 3, 7, 6, 8, 1, 8, 3, 5, 3, 3, 5, 4, 3],
    "GrandesChances": [2, 2, 3, 1, 2, 2, 0, 0, 2, 1, 5, 1, 1, 0, 2, 3, 0, 1, 0, 4],
})

# %%
rodada2.head()
# Out:
#          Times  Gols  Assistencias  FinalizaçaoGol  GrandesChances
# 0        Goias     1             1               6               2
# 1    Palmeiras     1             0               6               2
# 2    AmericaMG     4             3               9               3
# 3    Juventude     1             1               4               1
# 4  Corinthians     3             2               4               2

# %%
#Criando um arquivo csv com o dataframe
#rodada2.to_csv('rodada2_Br.csv')

# %%
plt.figure(figsize=(18, 6))
plt.plot(rodada2.loc[:, "Times"], rodada2.loc[:, "Assistencias"], color='blue', label='Assistencias')
plt.plot(rodada2.loc[:, "Times"], rodada2.loc[:, "FinalizaçaoGol"], color='green', label='FinalizaçaoGol')
plt.plot(rodada2.loc[:, "Times"], rodada2.loc[:, "GrandesChances"], color='black', label='GrandesChances')
plt.plot(rodada2.loc[:, "Times"], rodada2.loc[:, "Gols"], color='red', label='Gols')
plt.xticks(rotation=40, fontsize=16, fontweight='bold')
plt.yticks(np.arange(0, 10, 1), fontsize=12, fontweight='bold')
plt.title('Rodada 2 do Brasileirão: Estatística de: Gols x Assistências x Finalizações no gol x Grandes chances', fontsize=16, fontweight='bold', fontstyle='italic')
plt.legend()

# %%
corr_mat = rodada2[['Gols', 'Assistencias', 'FinalizaçaoGol', 'GrandesChances']].corr()
mask = np.array(corr_mat)
mask[np.tril_indices_from(mask)] = False
sns.heatmap(corr_mat, mask=mask, square=True, annot=True)
plt.title('Correlação dos índices', fontsize=16, fontweight='bold', fontstyle='italic')
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# ###Analise Brasileirão Rodada 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
rodada3 = pd.DataFrame({
    "Times": [ ],
    "Gols":           [],
    "Assistencias":   [],
    "FinalizaçaoGol": [],
    "GrandesChances": [],

(}

# %%
rodada.head()

# %%
plt.figure(figsize=(18, 6))
plt.plot(rodada3.loc[:, "Times"], rodada3.loc[:, "Assistencias"], color='blue', label='Assistencias')
plt.plot(rodada3.loc[:, "Times"], rodada3.loc[:, "FinalizaçaoGol"], color='green', label='FinalizaçaoGol')
plt.plot(rodada3.loc[:, "Times"], rodada3.loc[:, "GrandesChances"], color='black', label='GrandesChances')
plt.plot(rodada3.loc[:, "Times"], rodada3.loc[:, "Gols"], color='red', label='Gols')
plt.xticks(rotation=40, fontsize=16, fontweight='bold')
plt.yticks(np.arange(0, 10, 1), fontsize=12, fontweight='bold')
plt.title('Rodada 2 do Brasileirão: Estatística de: Gols x Assistências x Finalizações no gol x Grandes chances', fontsize=16, fontweight='bold', fontstyle='italic')
plt.legend()

# %%
corr_mat = rodada3[['Gols', 'Assistencias', 'FinalizaçaoGol', 'GrandesChances']].corr()
mask = np.array(corr_mat)
mask[np.tril_indices_from(mask)] = False
sns.heatmap(corr_mat, mask=mask, square=True, annot=True)
plt.title('Correlação dos índices', fontsize=16, fontweight='bold', fontstyle='italic')
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# ###Área de Automatização

# %%
listaTimes = []
listaGols = []
listaAssistencia = []
listaFinalizaçaoGol = []
listaGrandesChances = []
arquivo = ''

# %%
while True:
      times = input("Nome do time: ")
      gols = int(input("Gols marcados: "))
      assist = int(input("Assistências: "))
      finalização = int(input("Chutes no gol: "))
      chances = int(input("Grandes chances + bola na trave: "))
      botão = input("Digite ok p/ parar ou Clica em Concluir: ").lower()
      listaTimes.append(times)
      listaGols.append(gols)
      listaAssistencia.append(assist)
      listaGrandesChances.append(chances)
      listaFinalizaçaoGol.append(finalização)
      if botão == 'ok':
        print('Obrigado por ajudar.')
        break
      elif len(listaTimes) == 20:
        print('Concluído.')
        break
      else:
        continue
rodada2 = pd.DataFrame ({
      "Times" : listaTimes,
      "Gols" : listaGols,
      "Assistências" : listaAssistencia,
      "Finalização Gol" : listaFinalizaçaoGol,
      "Grandes chances" : listaGrandesChances      
})
# Out:
# Nome do time: df
# Gols marcados: 3
# Assistências: 2
# Chutes no gol: 3
# Grandes chances + bola na trave: 3
# Digite ok p/ parar ou Clica em Concluir: ok
# Obrigado por ajudar.

# %%
#Criando um arquivo csv com o dataframe
arquivo = input('Digite o nome do arquivo do qual será criado com a entrada de dados: ')
rodada3.to_csv('{}.csv'.format(arquivo))
# Out:
# Digite o nome do arquivo do qual será criado com a entrada de dados: rod

# %%
rodada2b = pd.read_csv('/content/rodada2_BrTeste.csv')
rodada2c = pd.read_csv('/content/rodada2_BrTeste2.csv')

# %%
#m = pd.merge(tabela_1, tabela_2, how = 'inner', on = 'Nome')
m = pd.merge(rodada2b, rpdada2c, how='outer')

# %%
t =pd.concat([rodada2b, rodada2c]).sort_values(by='Gols', ascending=False) 
t.drop(columns=['Unnamed: 0'], axis=0, inplace=True)
t.head()
#df.drop(['B', 'C'], axis=1)
#rodada_tot = pd.concat([rodada2b, rodada2c])
#rodada_tot.head()
